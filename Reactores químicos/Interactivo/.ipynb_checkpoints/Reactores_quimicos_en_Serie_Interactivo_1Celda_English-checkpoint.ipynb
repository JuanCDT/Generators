# %%
# Reactores Químicos en Serie. 
## Determinación del volumen de n reactores Mezcla Perfecta en serie


#%matplotlib notebook
import numpy as np
from sympy import pretty_print as pp, latex
from scipy import optimize
from scipy.integrate import ode
import matplotlib.pyplot as mpl
import matplotlib.patches as patches
import random
import math
import ipywidgets as widgets
import IPython.core.display as di
from ipywidgets import interact, IntSlider, FloatSlider,fixed
import notebook
from IPython.display import clear_output, display, HTML, Image,Math, Latex
from IPython.external import mathjax

FigureSize=(10,5)


def generador_parametros(): #generación de parámetros de la ecuación cinética y Temperatura de trabajo
    global k, Ea, Ln_K0,T,Qv,Ca0,Xas
    
    Ea=random.uniform(40.,80.0)
    Ca0=round(random.uniform(5.,10.),1)
    Xas=round(random.uniform(0.5,1.0),2)
    Ln_K0 = random.uniform(15.,25.)
    T= random.uniform(40., 80.) #Temperatura en ºC
    T1=T+273.15 #Temperatura en K
    k = math.exp(Ln_K0)*math.exp(Ea*(-1000.)/(8.31*(T1))) #Para este caso n=1
    Qv=round(random.uniform(50,100),0) #Caudal volumétrico en L/min
    
    return k,T,Qv,Ca0,Xas


def Reactor_MP(Qv,k,Ca0,V): #Cálculo del volumen del rtor MP
    Cas=Ca0/(1+k*V/Qv)
    return Cas


def Bateria_Serie_EC_Diseno(V,Qv,k,Ca0,Xas,N):    
    Ca_salida=Ca0*(1-Xas)
    value=Ca_salida-Ca0/(1+k*V/Qv)**N 
    return value

def Volumen_Rtor_Bateria(Qv,k,Ca0,Xas,N):
    volumen=optimize.fsolve(Bateria_Serie_EC_Diseno, 1, args=(Qv,k,Ca0,Xas,N), xtol=1e-06, maxfev=500)
    return volumen


def Bateria_Serie_MP(V,N,Qv,k,Ca0):
    Concentraciones = [Ca0]
    Conversiones=[0]
    for i in range(N):
        Concentraciones.append(Reactor_MP(Qv, k, Concentraciones[i], V))
        xa=(Concentraciones[0]-Concentraciones[-1])/Concentraciones[0]
        Conversiones.append(xa)
    return Concentraciones,Conversiones
            

def f(Xa,V,n,k,Ca0,Qv): #ecuación cinética

    t_residencia=(Qv)/(k*(Ca0**(n-1))*(1-Xa)**n)
    return t_residencia


def Reactor_MP_Volumen(Qv,n,k,Ca0,Xas): #Cálculo del volumen del rtor MP

    Volumen=Qv*(Ca0*Xas/(((Ca0*(1-Xas))**n)*k))
    return Volumen


def Reactor_FP(Qv,n,k,Ca0,Xas):
       
    incr_Xa=0.005

    V = []
    Xa = []

    Xa0=0.
    V_inicial=0.
    
    V.append(0.)
    Xa.append(0.)

    r = ode(f).set_integrator('vode', method='bdf', nsteps=1000, atol = 1.0e-05, rtol = 1.0e-05)
    r.set_initial_value(V_inicial,Xa0).set_f_params(n,k,Ca0,Qv)
    #print(t[0], Ca[0])
    #print ('r_t: ',r.t,'Ca0: ',r.y)

    while r.successful() and Xa[-1]<=Xas:
        r.integrate(r.t + incr_Xa)
        #Ca[k1]=r.y
        V.append(r.y)
        Xa.append(r.t)
        #print ('tiempo:', '%.2f' % t[k], 'Ca:','%.4f'%Ca[k])
        XaFP=Xa

    return V[-1],XaFP


display(HTML('<h1 style="color:#000000"><strong>Continuous Flow Stirred-Tank Reactor (CSTR) in Series).</strong></h1>'))
display(HTML('<h2>Determination of the volume of n reactors CSTR in series</br> </br> </br>  </h2>' ))


display(HTML('''<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide code')
    }
    code_shown = !code_shown
  }

  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show code"></form>'''))

display(HTML('<h1 style="color:#000000"">Remember that a potential type kinetic equation is described by the following equation:</br>  </h1>' ))
display(Math(r'r=k\cdot C_A^n'))



display(HTML('<h1 style="color:#000000"><strong>The (generated) parameters of the system are:</strong></h1>'))

k,T,Qv,Ca0,Xas=generador_parametros()

print ("Ln k: ",'%.3f' % math.log(k),  '; T (ºC): ','%.1f' % T, '; Qv (L/min): ','%.1f' % Qv,
       '; Ca0 (mol/L): ','%.2f' % Ca0,  '; Xas: ','%.2f' % Xas)

display(HTML('<h1 style="color:#000000"><strong>Scheme for N Reactors (CSTR) in Series. </strong></h1>' ))
display(Image(filename='./Imagenes/Rtor Mezcla Completa en serie.jpeg'))



display(HTML('<h1 style="color:#000000"><strong>Design equation for a single CSTR:</br> </strong></h1>' ))
display(Math(r'\frac{V}{Q_V}=\frac{C_A^{outlet} \cdot X_A}{(-R_A)}'))
display(HTML('<h1 style="color:#000000"><strong>Design equation for a series of CSTR (reaction order (n)=1):</br> </strong></h1>' ))
display(Math(r'C_{A_{outlet}}^{reactor\ N}=\frac{C_{A_{inlet}}^{reactor\ 1}}{\left (  1 + k \frac{V}{Q_V} \right )^N }'))
# Out:
# <h1 style="color:#000000"><strong>Continuous Flow Stirred-Tank Reactor (CSTR) in Series).</strong></h1>
# <h2>Determination of the volume of n reactors CSTR in series</br> </br> </br>  </h2>
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show code"></form>
# <h1 style="color:#000000"">Remember that a potential type kinetic equation is described by the following equation:</br>  </h1>
# $$r=k\cdot C_A^n$$
# <h1 style="color:#000000"><strong>The (generated) parameters of the system are:</strong></h1>
# Ln k:  0.912 ; T (ºC):  72.3 ; Qv (L/min):  68.0 ; Ca0 (mol/L):  6.80 ; Xas:  0.63
# <h1 style="color:#000000"><strong>Scheme for N Reactors (CSTR) in Series. </strong></h1>
# <h1 style="color:#000000"><strong>Design equation for a single CSTR:</br> </strong></h1>
# $$\frac{V}{Q_V}=\frac{C_A^{outlet} \cdot X_A}{(-R_A)}$$
# <h1 style="color:#000000"><strong>Design equation for a series of CSTR (reaction order (n)=1):</br> </strong></h1>
# $$C_{A_{outlet}}^{reactor\ N}=\frac{C_{A_{inlet}}^{reactor\ 1}}{\left (  1 + k \frac{V}{Q_V} \right )^N }$$

# %%
parametros=[Qv,k,Ca0,Xas]


def Graficas(N,p):
    
    Qv,k,Ca0,Xas=p
    Volumen_Rtor_MP=Volumen_Rtor_Bateria(Qv,k,Ca0,Xas,N)
    V_FP,Xa_FP=Reactor_FP(Qv,1,k,Ca0,Xas)
    
    
    Concentraciones,Conversiones=Bateria_Serie_MP(Volumen_Rtor_MP,N,Qv,k,Ca0)

    Oscuridad=np.arange(1/N, 1+1/N, 1/N)


    fig1 = mpl.figure(figsize=FigureSize)
    mpl.clf()
    ax1 = fig1.add_subplot(121)
    height=[]
    for i in range(N):
        width=(Conversiones[i+1]-Conversiones[i])
        height.append(1/(k*Concentraciones[i+1]))
        ax1.add_patch(
        patches.Rectangle(
                    (Conversiones[i], 0.0),   # (xa_entrada, y=o)
                    width,          # width - (xa_salida-xa_entrada)
                    height[i],          # height - (1/-Ra)
                    alpha=Oscuridad[i]
                )
            )

    x_FP=np.asarray(Xa_FP)
    y_FP=1/(k*Ca0*(1-x_FP))
    mpl.plot(x_FP,y_FP,'k-', linewidth = 2)

    mpl.ylim((0, 1.05*max(height)))
    mpl.ylabel('1/-Ra')
    mpl.xlabel('Xa')

    Concentracion_inverso=sorted(Concentraciones,reverse=True)

    ax2 = fig1.add_subplot(122)
    for i in range(N):
        width=(Concentracion_inverso[i+1]-Concentracion_inverso[i])
        ax2.add_patch(
        patches.Rectangle(
                    (Concentracion_inverso[i], 0.0),   # (xa_entrada, y=o)
                    width,          # width - (xa_salida-xa_entrada)
                    height[i],          # height - (1/-Ra)
                    alpha=Oscuridad[i]
                )
            )

    Ca_FP=Ca0*(1-x_FP)
    mpl.plot(Ca_FP,y_FP,'k-', linewidth = 2)

    mpl.xlim((min(Concentracion_inverso)-0.5, 0.5+max(Concentracion_inverso)))
    mpl.ylim((0, 1.05*max(height)))

    mpl.ylabel('1/-Ra')
    mpl.xlabel('Ca')
    #mpl.rcParams['figure.figsize'] = (4., 2.)
    #mpl.rcParams['axes.titlesize'] ='large'
    #mpl.rcParams['axes.labelsize']= 'medium' 
    #mpl.rcParams['figure.dpi']= 600 
    mpl.tight_layout()    
    mpl.show()
    
    print ('Volume of each reactor: ','%.1f' % Volumen_Rtor_MP,' L')    
    print ('Total volume of the system: ','%.1f' % (Volumen_Rtor_MP*N),' L \n')
    print ('Volume of a single CSTR reactor - for the same final conversion -: ','%.1f' % Reactor_MP_Volumen(Qv,1,k,Ca0,Xas),' L')
    print ('Volume of a single Plug Flow Reactor (PFR) - for the same final conversion -: ','%.1f' % V_FP,' L')
    
s1=widgets.IntSlider(
    value=5.0,
    min=1.0,
    max=20.0,
    step=1,
    description='Nº Reactors:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='i',
    slider_color='lightblue')

interact(Graficas,N=s1,p=fixed([Qv,k,Ca0,Xas]))
# Out:
# <function __main__.Graficas>

# %%
display(HTML('''

<footer id="attribution" style="float:right; color:#999; background:#fff;">
Programado con Jupyter. </footer>'''))
# Out:
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Programado con Jupyter. </footer>
